# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import seaborn as sns

# %%
data=pd.read_csv('ML_Data_48.csv')

# %%
data=data.drop(['Z_jerk_mean', 'X_jerk_mean', 'total_jerk_mean', 'Y_jerk_mean','X_jerk_mean','X_jerk_min', 'X_min', 'timestamp_range', 'Y_mean', 'X_mean', 'X_max','Z_mean', 'X_jerk_max', 'X_jerk_range', 'X_range'], axis=1)

# %%
data.columns
# Out:
# Index(['label', 'X_rms', 'X_std', 'Y_min', 'Y_max', 'Y_range', 'Y_rms',
#        'Y_std', 'Z_min', 'Z_max', 'Z_range', 'Z_rms', 'Z_std', 'X_jerk_rms',
#        'X_jerk_std', 'Y_jerk_min', 'Y_jerk_max', 'Y_jerk_range', 'Y_jerk_rms',
#        'Y_jerk_std', 'Z_jerk_min', 'Z_jerk_max', 'Z_jerk_range', 'Z_jerk_rms',
#        'Z_jerk_std', 'total_jerk_min', 'total_jerk_max', 'total_jerk_range',
#        'total_jerk_rms', 'total_jerk_std', 'SMA', 'X_entropy', 'Y_entropy',
#        'Z_entropy'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

# %%
x=data.drop(['label'], axis=1)
y=data['label']

# %%
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
x_train, x_t, y_train, y_t= train_test_split(x,y,test_size=0.3, random_state=42)
x_train.shape, x_t.shape
# Out:
# ((2614, 33), (1121, 33))

# %%
x_val, x_test, y_val, y_test= train_test_split(x_t, y_t, test_size=0.15, random_state=42)
x_val.shape, x_test.shape
# Out:
# ((952, 33), (169, 33))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import Adam, SGD
# Out:
# 2024-12-09 12:47:27.075921: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-09 12:47:27.141547: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-09 12:47:27.472890: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-09 12:47:27.472932: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-09 12:47:27.474692: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-09 12:47:27.623086: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-09 12:47:27.625050: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-09 12:47:28.460009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential([
    Dense(1024, activation='relu'),
    Dropout(0.7),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(64, activation='relu'),
    Dropout(0.1),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(8, activation='softmax')
])

# %%
initial_learning_rate = 0.01
lr_schedule = ExponentialDecay(
    initial_learning_rate,      # Starting learning rate
    decay_steps=1000,         # How often to decay the learning rate
    decay_rate=0.96,            # The decay rate
    staircase=True              # Apply decay in discrete steps
)

# early_stopping = EarlyStopping(monitor='val_loss', patience=70, restore_best_weights=True)

# %%
# model.compile(optimizer=SGD(learning_rate=lr_schedule, 
#                             momentum=0.97, 
#                             nesterov=True),  # Enable Nesterov momentum
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(),
#               metrics=['accuracy'])

# %%
model.compile(optimizer=Adam(), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                                epochs=500,
                                batch_size=64,
                                validation_data= (x_val, y_val),
                                verbose=2)
# Out:
# Epoch 1/500
# 41/41 - 1s - loss: 1.9273 - accuracy: 0.2035 - val_loss: 1.8367 - val_accuracy: 0.2574 - 810ms/epoch - 20ms/step
# Epoch 2/500
# 41/41 - 0s - loss: 1.7673 - accuracy: 0.2796 - val_loss: 1.7007 - val_accuracy: 0.3487 - 113ms/epoch - 3ms/step
# Epoch 3/500
# 41/41 - 0s - loss: 1.6652 - accuracy: 0.3573 - val_loss: 1.5376 - val_accuracy: 0.4191 - 114ms/epoch - 3ms/step
# Epoch 4/500
# 41/41 - 0s - loss: 1.5759 - accuracy: 0.3841 - val_loss: 1.4830 - val_accuracy: 0.4170 - 122ms/epoch - 3ms/step
# Epoch 5/500
# 41/41 - 0s - loss: 1.5015 - accuracy: 0.4254 - val_loss: 1.3730 - val_accuracy: 0.4506 - 123ms/epoch - 3ms/step
# Epoch 6/500
# 41/41 - 0s - loss: 1.4689 - accuracy: 0.4507 - val_loss: 1.3479 - val_accuracy: 0.4674 - 123ms/epoch - 3ms/step
# Epoch 7/500
# 41/41 - 0s - loss: 1.4283 - accuracy: 0.4568 - val_loss: 1.3223 - val_accuracy: 0.4884 - 116ms/epoch - 3ms/step
# Epoch 8/500
# 41/41 - 0s - loss: 1.3857 - accuracy: 0.4813 - val_loss: 1.2923 - val_accuracy: 0.5021 - 109ms/epoch - 3ms/step
# Epoch 9/500
# 41/41 - 0s - loss: 1.3656 - accuracy: 0.4820 - val_loss: 1.2706 - val_accuracy: 0.5126 - 112ms/epoch - 3ms/step
# Epoch 10/500
# 41/41 - 0s - loss: 1.3285 - accuracy: 0.5031 - val_loss: 1.2578 - val_accuracy: 0.5189 - 111ms/epoch - 3ms/step
# Epoch 11/500
# 41/41 - 0s - loss: 1.3113 - accuracy: 0.4958 - val_loss: 1.2050 - val_accuracy: 0.5336 - 113ms/epoch - 3ms/step
# Epoch 12/500
# 41/41 - 0s - loss: 1.2967 - accuracy: 0.5088 - val_loss: 1.2329 - val_accuracy: 0.5168 - 113ms/epoch - 3ms/step
# Epoch 13/500
# 41/41 - 0s - loss: 1.2675 - accuracy: 0.5119 - val_loss: 1.1862 - val_accuracy: 0.5473 - 113ms/epoch - 3ms/step
# Epoch 14/500
# 41/41 - 0s - loss: 1.2873 - accuracy: 0.5325 - val_loss: 1.1755 - val_accuracy: 0.5483 - 112ms/epoch - 3ms/step
# Epoch 15/500
# 41/41 - 0s - loss: 1.2617 - accuracy: 0.5394 - val_loss: 1.1551 - val_accuracy: 0.5546 - 112ms/epoch - 3ms/step
# Epoch 16/500
# 41/41 - 0s - loss: 1.2333 - accuracy: 0.5379 - val_loss: 1.1250 - val_accuracy: 0.5567 - 111ms/epoch - 3ms/step
# Epoch 17/500
# 41/41 - 0s - loss: 1.2195 - accuracy: 0.5314 - val_loss: 1.1235 - val_accuracy: 0.5725 - 113ms/epoch - 3ms/step
# Epoch 18/500
# 41/41 - 0s - loss: 1.1839 - accuracy: 0.5624 - val_loss: 1.0953 - val_accuracy: 0.5662 - 112ms/epoch - 3ms/step
# Epoch 19/500
# 41/41 - 0s - loss: 1.1763 - accuracy: 0.5685 - val_loss: 1.1249 - val_accuracy: 0.5851 - 112ms/epoch - 3ms/step
# Epoch 20/500
# 41/41 - 0s - loss: 1.1870 - accuracy: 0.5520 - val_loss: 1.0786 - val_accuracy: 0.5872 - 112ms/epoch - 3ms/step
# Epoch 21/500
# 41/41 - 0s - loss: 1.1441 - accuracy: 0.5750 - val_loss: 1.0820 - val_accuracy: 0.6019 - 113ms/epoch - 3ms/step
# Epoch 22/500
# 41/41 - 0s - loss: 1.1450 - accuracy: 0.5761 - val_loss: 1.0463 - val_accuracy: 0.5977 - 114ms/epoch - 3ms/step
# Epoch 23/500
# 41/41 - 0s - loss: 1.1494 - accuracy: 0.5685 - val_loss: 1.0584 - val_accuracy: 0.5998 - 114ms/epoch - 3ms/step
# Epoch 24/500
# 41/41 - 0s - loss: 1.0911 - accuracy: 0.5930 - val_loss: 1.0230 - val_accuracy: 0.6061 - 113ms/epoch - 3ms/step
# Epoch 25/500
# 41/41 - 0s - loss: 1.1004 - accuracy: 0.5826 - val_loss: 1.0191 - val_accuracy: 0.6113 - 116ms/epoch - 3ms/step
# Epoch 26/500
# 41/41 - 0s - loss: 1.1026 - accuracy: 0.5861 - val_loss: 1.0064 - val_accuracy: 0.6229 - 113ms/epoch - 3ms/step
# Epoch 27/500
# 41/41 - 0s - loss: 1.0876 - accuracy: 0.5899 - val_loss: 1.0103 - val_accuracy: 0.6313 - 112ms/epoch - 3ms/step
# Epoch 28/500
# 41/41 - 0s - loss: 1.0867 - accuracy: 0.5933 - val_loss: 1.0120 - val_accuracy: 0.6355 - 113ms/epoch - 3ms/step
# Epoch 29/500
# 41/41 - 0s - loss: 1.0606 - accuracy: 0.6052 - val_loss: 1.0089 - val_accuracy: 0.6334 - 114ms/epoch - 3ms/step
# Epoch 30/500
# 41/41 - 0s - loss: 1.0482 - accuracy: 0.6056 - val_loss: 0.9923 - val_accuracy: 0.6450 - 115ms/epoch - 3ms/step
# Epoch 31/500
# 41/41 - 0s - loss: 1.0402 - accuracy: 0.6174 - val_loss: 0.9664 - val_accuracy: 0.6513 - 113ms/epoch - 3ms/step
# Epoch 32/500
# 41/41 - 0s - loss: 1.0301 - accuracy: 0.6151 - val_loss: 0.9610 - val_accuracy: 0.6460 - 114ms/epoch - 3ms/step
# Epoch 33/500
# 41/41 - 0s - loss: 1.0296 - accuracy: 0.6136 - val_loss: 0.9431 - val_accuracy: 0.6649 - 113ms/epoch - 3ms/step
# Epoch 34/500
# 41/41 - 0s - loss: 1.0279 - accuracy: 0.6243 - val_loss: 0.9423 - val_accuracy: 0.6397 - 113ms/epoch - 3ms/step
# Epoch 35/500
# 41/41 - 0s - loss: 1.0244 - accuracy: 0.6094 - val_loss: 0.9415 - val_accuracy: 0.6555 - 113ms/epoch - 3ms/step
# Epoch 36/500
# 41/41 - 0s - loss: 1.0125 - accuracy: 0.6274 - val_loss: 0.9183 - val_accuracy: 0.6607 - 113ms/epoch - 3ms/step
# Epoch 37/500
# 41/41 - 0s - loss: 0.9971 - accuracy: 0.6285 - val_loss: 0.9077 - val_accuracy: 0.6702 - 113ms/epoch - 3ms/step
# Epoch 38/500
# 41/41 - 0s - loss: 0.9852 - accuracy: 0.6362 - val_loss: 0.9077 - val_accuracy: 0.6744 - 111ms/epoch - 3ms/step
# Epoch 39/500
# 41/41 - 0s - loss: 0.9794 - accuracy: 0.6350 - val_loss: 0.9096 - val_accuracy: 0.6702 - 113ms/epoch - 3ms/step
# Epoch 40/500
# 41/41 - 0s - loss: 0.9781 - accuracy: 0.6373 - val_loss: 0.9090 - val_accuracy: 0.6733 - 113ms/epoch - 3ms/step
# Epoch 41/500
# 41/41 - 0s - loss: 0.9714 - accuracy: 0.6377 - val_loss: 0.8744 - val_accuracy: 0.6796 - 113ms/epoch - 3ms/step
# Epoch 42/500
# 41/41 - 0s - loss: 0.9597 - accuracy: 0.6480 - val_loss: 0.8932 - val_accuracy: 0.6796 - 114ms/epoch - 3ms/step
# Epoch 43/500
# 41/41 - 0s - loss: 0.9605 - accuracy: 0.6492 - val_loss: 0.8821 - val_accuracy: 0.6859 - 113ms/epoch - 3ms/step
# Epoch 44/500
# 41/41 - 0s - loss: 0.9606 - accuracy: 0.6477 - val_loss: 0.8993 - val_accuracy: 0.6754 - 113ms/epoch - 3ms/step
# Epoch 45/500
# 41/41 - 0s - loss: 0.9497 - accuracy: 0.6546 - val_loss: 0.8714 - val_accuracy: 0.6828 - 112ms/epoch - 3ms/step
# Epoch 46/500
# 41/41 - 0s - loss: 0.9212 - accuracy: 0.6546 - val_loss: 0.8491 - val_accuracy: 0.6933 - 118ms/epoch - 3ms/step
# Epoch 47/500
# 41/41 - 0s - loss: 0.9228 - accuracy: 0.6591 - val_loss: 0.8576 - val_accuracy: 0.6996 - 116ms/epoch - 3ms/step
# Epoch 48/500
# 41/41 - 0s - loss: 0.9376 - accuracy: 0.6530 - val_loss: 0.8568 - val_accuracy: 0.6796 - 114ms/epoch - 3ms/step
# Epoch 49/500
# 41/41 - 0s - loss: 0.9443 - accuracy: 0.6542 - val_loss: 0.8614 - val_accuracy: 0.7006 - 112ms/epoch - 3ms/step
# Epoch 50/500
# 41/41 - 0s - loss: 0.9227 - accuracy: 0.6523 - val_loss: 0.8585 - val_accuracy: 0.6870 - 113ms/epoch - 3ms/step
# Epoch 51/500
# 41/41 - 0s - loss: 0.9167 - accuracy: 0.6630 - val_loss: 0.8591 - val_accuracy: 0.6912 - 113ms/epoch - 3ms/step
# Epoch 52/500
# 41/41 - 0s - loss: 0.8857 - accuracy: 0.6691 - val_loss: 0.8447 - val_accuracy: 0.6880 - 114ms/epoch - 3ms/step
# Epoch 53/500
# 41/41 - 0s - loss: 0.9118 - accuracy: 0.6614 - val_loss: 0.8506 - val_accuracy: 0.6943 - 114ms/epoch - 3ms/step
# Epoch 54/500
# 41/41 - 0s - loss: 0.9094 - accuracy: 0.6687 - val_loss: 0.8579 - val_accuracy: 0.6796 - 116ms/epoch - 3ms/step
# Epoch 55/500
# 41/41 - 0s - loss: 0.8949 - accuracy: 0.6729 - val_loss: 0.8470 - val_accuracy: 0.7069 - 110ms/epoch - 3ms/step
# Epoch 56/500
# 41/41 - 0s - loss: 0.9082 - accuracy: 0.6737 - val_loss: 0.8391 - val_accuracy: 0.7006 - 114ms/epoch - 3ms/step
# Epoch 57/500
# 41/41 - 0s - loss: 0.8807 - accuracy: 0.6909 - val_loss: 0.8448 - val_accuracy: 0.7048 - 111ms/epoch - 3ms/step
# Epoch 58/500
# 41/41 - 0s - loss: 0.8612 - accuracy: 0.6890 - val_loss: 0.8199 - val_accuracy: 0.7059 - 115ms/epoch - 3ms/step
# Epoch 59/500
# 41/41 - 0s - loss: 0.8724 - accuracy: 0.6829 - val_loss: 0.8107 - val_accuracy: 0.7132 - 112ms/epoch - 3ms/step
# Epoch 60/500
# 41/41 - 0s - loss: 0.8607 - accuracy: 0.6832 - val_loss: 0.8298 - val_accuracy: 0.7069 - 112ms/epoch - 3ms/step
# Epoch 61/500
# 41/41 - 0s - loss: 0.8470 - accuracy: 0.6852 - val_loss: 0.8207 - val_accuracy: 0.7017 - 113ms/epoch - 3ms/step
# Epoch 62/500
# 41/41 - 0s - loss: 0.8527 - accuracy: 0.6829 - val_loss: 0.8082 - val_accuracy: 0.7153 - 111ms/epoch - 3ms/step
# Epoch 63/500
# 41/41 - 0s - loss: 0.8457 - accuracy: 0.6867 - val_loss: 0.8002 - val_accuracy: 0.7206 - 112ms/epoch - 3ms/step
# Epoch 64/500
# 41/41 - 0s - loss: 0.8289 - accuracy: 0.6943 - val_loss: 0.8026 - val_accuracy: 0.7111 - 112ms/epoch - 3ms/step
# Epoch 65/500
# 41/41 - 0s - loss: 0.8552 - accuracy: 0.6955 - val_loss: 0.7864 - val_accuracy: 0.7195 - 112ms/epoch - 3ms/step
# Epoch 66/500
# 41/41 - 0s - loss: 0.8424 - accuracy: 0.6982 - val_loss: 0.8215 - val_accuracy: 0.7101 - 113ms/epoch - 3ms/step
# Epoch 67/500
# 41/41 - 0s - loss: 0.8485 - accuracy: 0.6920 - val_loss: 0.8328 - val_accuracy: 0.7080 - 112ms/epoch - 3ms/step
# Epoch 68/500
# 41/41 - 0s - loss: 0.8353 - accuracy: 0.6947 - val_loss: 0.7915 - val_accuracy: 0.7111 - 112ms/epoch - 3ms/step
# Epoch 69/500
# 41/41 - 0s - loss: 0.8255 - accuracy: 0.6978 - val_loss: 0.7777 - val_accuracy: 0.7143 - 112ms/epoch - 3ms/step
# Epoch 70/500
# 41/41 - 0s - loss: 0.8344 - accuracy: 0.6913 - val_loss: 0.7971 - val_accuracy: 0.7143 - 111ms/epoch - 3ms/step
# Epoch 71/500
# 41/41 - 0s - loss: 0.8431 - accuracy: 0.6963 - val_loss: 0.7963 - val_accuracy: 0.7174 - 115ms/epoch - 3ms/step
# Epoch 72/500
# 41/41 - 0s - loss: 0.7931 - accuracy: 0.6974 - val_loss: 0.7743 - val_accuracy: 0.7227 - 130ms/epoch - 3ms/step
# Epoch 73/500
# 41/41 - 0s - loss: 0.8137 - accuracy: 0.7093 - val_loss: 0.7761 - val_accuracy: 0.7185 - 134ms/epoch - 3ms/step
# Epoch 74/500
# 41/41 - 0s - loss: 0.8026 - accuracy: 0.7062 - val_loss: 0.7798 - val_accuracy: 0.7269 - 134ms/epoch - 3ms/step
# Epoch 75/500
# 41/41 - 0s - loss: 0.8072 - accuracy: 0.7031 - val_loss: 0.8086 - val_accuracy: 0.7122 - 124ms/epoch - 3ms/step
# Epoch 76/500
# 41/41 - 0s - loss: 0.8141 - accuracy: 0.7024 - val_loss: 0.7943 - val_accuracy: 0.7164 - 120ms/epoch - 3ms/step
# Epoch 77/500
# 41/41 - 0s - loss: 0.7909 - accuracy: 0.7169 - val_loss: 0.7781 - val_accuracy: 0.7216 - 129ms/epoch - 3ms/step
# Epoch 78/500
# 41/41 - 0s - loss: 0.7685 - accuracy: 0.7269 - val_loss: 0.7740 - val_accuracy: 0.7185 - 133ms/epoch - 3ms/step
# Epoch 79/500
# 41/41 - 0s - loss: 0.7929 - accuracy: 0.7012 - val_loss: 0.7728 - val_accuracy: 0.7237 - 128ms/epoch - 3ms/step
# Epoch 80/500
# 41/41 - 0s - loss: 0.7773 - accuracy: 0.7127 - val_loss: 0.7888 - val_accuracy: 0.7153 - 125ms/epoch - 3ms/step
# Epoch 81/500
# 41/41 - 0s - loss: 0.7866 - accuracy: 0.7192 - val_loss: 0.7781 - val_accuracy: 0.7353 - 117ms/epoch - 3ms/step
# Epoch 82/500
# 41/41 - 0s - loss: 0.7801 - accuracy: 0.7150 - val_loss: 0.7686 - val_accuracy: 0.7185 - 116ms/epoch - 3ms/step
# Epoch 83/500
# 41/41 - 0s - loss: 0.7622 - accuracy: 0.7211 - val_loss: 0.7651 - val_accuracy: 0.7353 - 126ms/epoch - 3ms/step
# Epoch 84/500
# 41/41 - 0s - loss: 0.7658 - accuracy: 0.7207 - val_loss: 0.7745 - val_accuracy: 0.7237 - 130ms/epoch - 3ms/step
# Epoch 85/500
# 41/41 - 0s - loss: 0.7509 - accuracy: 0.7184 - val_loss: 0.7561 - val_accuracy: 0.7206 - 131ms/epoch - 3ms/step
# Epoch 86/500
# 41/41 - 0s - loss: 0.7755 - accuracy: 0.7138 - val_loss: 0.7567 - val_accuracy: 0.7321 - 127ms/epoch - 3ms/step
# Epoch 87/500
# 41/41 - 0s - loss: 0.7333 - accuracy: 0.7345 - val_loss: 0.7565 - val_accuracy: 0.7216 - 129ms/epoch - 3ms/step
# Epoch 88/500
# 41/41 - 0s - loss: 0.7554 - accuracy: 0.7234 - val_loss: 0.7541 - val_accuracy: 0.7290 - 126ms/epoch - 3ms/step
# Epoch 89/500
# 41/41 - 0s - loss: 0.7500 - accuracy: 0.7288 - val_loss: 0.7512 - val_accuracy: 0.7300 - 115ms/epoch - 3ms/step
# Epoch 90/500
# 41/41 - 0s - loss: 0.7553 - accuracy: 0.7318 - val_loss: 0.7660 - val_accuracy: 0.7185 - 118ms/epoch - 3ms/step
# Epoch 91/500
# 41/41 - 0s - loss: 0.7484 - accuracy: 0.7211 - val_loss: 0.7739 - val_accuracy: 0.7227 - 119ms/epoch - 3ms/step
# Epoch 92/500
# 41/41 - 0s - loss: 0.7370 - accuracy: 0.7223 - val_loss: 0.7592 - val_accuracy: 0.7248 - 119ms/epoch - 3ms/step
# Epoch 93/500
# 41/41 - 0s - loss: 0.7494 - accuracy: 0.7257 - val_loss: 0.7329 - val_accuracy: 0.7311 - 124ms/epoch - 3ms/step
# Epoch 94/500
# 41/41 - 0s - loss: 0.7529 - accuracy: 0.7288 - val_loss: 0.7698 - val_accuracy: 0.7321 - 118ms/epoch - 3ms/step
# Epoch 95/500
# 41/41 - 0s - loss: 0.7437 - accuracy: 0.7265 - val_loss: 0.7397 - val_accuracy: 0.7447 - 117ms/epoch - 3ms/step
# Epoch 96/500
# 41/41 - 0s - loss: 0.7327 - accuracy: 0.7318 - val_loss: 0.7212 - val_accuracy: 0.7437 - 121ms/epoch - 3ms/step
# Epoch 97/500
# 41/41 - 0s - loss: 0.7272 - accuracy: 0.7360 - val_loss: 0.7574 - val_accuracy: 0.7332 - 119ms/epoch - 3ms/step
# Epoch 98/500
# 41/41 - 0s - loss: 0.7392 - accuracy: 0.7406 - val_loss: 0.7190 - val_accuracy: 0.7384 - 133ms/epoch - 3ms/step
# Epoch 99/500
# 41/41 - 0s - loss: 0.7267 - accuracy: 0.7372 - val_loss: 0.7219 - val_accuracy: 0.7437 - 133ms/epoch - 3ms/step
# Epoch 100/500
# 41/41 - 0s - loss: 0.7154 - accuracy: 0.7311 - val_loss: 0.7170 - val_accuracy: 0.7468 - 128ms/epoch - 3ms/step
# Epoch 101/500
# 41/41 - 0s - loss: 0.7133 - accuracy: 0.7372 - val_loss: 0.7336 - val_accuracy: 0.7447 - 119ms/epoch - 3ms/step
# Epoch 102/500
# 41/41 - 0s - loss: 0.7004 - accuracy: 0.7540 - val_loss: 0.7098 - val_accuracy: 0.7416 - 123ms/epoch - 3ms/step
# Epoch 103/500
# 41/41 - 0s - loss: 0.6711 - accuracy: 0.7448 - val_loss: 0.7253 - val_accuracy: 0.7321 - 129ms/epoch - 3ms/step
# Epoch 104/500
# 41/41 - 0s - loss: 0.6670 - accuracy: 0.7548 - val_loss: 0.7163 - val_accuracy: 0.7447 - 128ms/epoch - 3ms/step
# Epoch 105/500
# 41/41 - 0s - loss: 0.6880 - accuracy: 0.7441 - val_loss: 0.7140 - val_accuracy: 0.7332 - 130ms/epoch - 3ms/step
# Epoch 106/500
# 41/41 - 0s - loss: 0.7114 - accuracy: 0.7448 - val_loss: 0.7036 - val_accuracy: 0.7437 - 118ms/epoch - 3ms/step
# Epoch 107/500
# 41/41 - 0s - loss: 0.7043 - accuracy: 0.7418 - val_loss: 0.7177 - val_accuracy: 0.7479 - 120ms/epoch - 3ms/step
# Epoch 108/500
# 41/41 - 0s - loss: 0.7267 - accuracy: 0.7330 - val_loss: 0.7211 - val_accuracy: 0.7416 - 116ms/epoch - 3ms/step
# Epoch 109/500
# 41/41 - 0s - loss: 0.7075 - accuracy: 0.7406 - val_loss: 0.7056 - val_accuracy: 0.7426 - 113ms/epoch - 3ms/step
# Epoch 110/500
# 41/41 - 0s - loss: 0.6761 - accuracy: 0.7490 - val_loss: 0.7041 - val_accuracy: 0.7468 - 112ms/epoch - 3ms/step
# Epoch 111/500
# 41/41 - 0s - loss: 0.6861 - accuracy: 0.7525 - val_loss: 0.7071 - val_accuracy: 0.7584 - 113ms/epoch - 3ms/step
# Epoch 112/500
# 41/41 - 0s - loss: 0.6999 - accuracy: 0.7448 - val_loss: 0.7054 - val_accuracy: 0.7500 - 115ms/epoch - 3ms/step
# Epoch 113/500
# 41/41 - 0s - loss: 0.6498 - accuracy: 0.7605 - val_loss: 0.6938 - val_accuracy: 0.7416 - 126ms/epoch - 3ms/step
# Epoch 114/500
# 41/41 - 0s - loss: 0.6701 - accuracy: 0.7624 - val_loss: 0.6918 - val_accuracy: 0.7563 - 124ms/epoch - 3ms/step
# Epoch 115/500
# 41/41 - 0s - loss: 0.6838 - accuracy: 0.7540 - val_loss: 0.6928 - val_accuracy: 0.7563 - 118ms/epoch - 3ms/step
# Epoch 116/500
# 41/41 - 0s - loss: 0.6740 - accuracy: 0.7536 - val_loss: 0.7014 - val_accuracy: 0.7468 - 112ms/epoch - 3ms/step
# Epoch 117/500
# 41/41 - 0s - loss: 0.6544 - accuracy: 0.7487 - val_loss: 0.7086 - val_accuracy: 0.7437 - 113ms/epoch - 3ms/step
# Epoch 118/500
# 41/41 - 0s - loss: 0.6821 - accuracy: 0.7525 - val_loss: 0.6968 - val_accuracy: 0.7553 - 112ms/epoch - 3ms/step
# Epoch 119/500
# 41/41 - 0s - loss: 0.6603 - accuracy: 0.7582 - val_loss: 0.7112 - val_accuracy: 0.7595 - 113ms/epoch - 3ms/step
# Epoch 120/500
# 41/41 - 0s - loss: 0.6597 - accuracy: 0.7601 - val_loss: 0.6867 - val_accuracy: 0.7405 - 119ms/epoch - 3ms/step
# Epoch 121/500
# 41/41 - 0s - loss: 0.6569 - accuracy: 0.7613 - val_loss: 0.7018 - val_accuracy: 0.7553 - 129ms/epoch - 3ms/step
# Epoch 122/500
# 41/41 - 0s - loss: 0.6524 - accuracy: 0.7751 - val_loss: 0.7098 - val_accuracy: 0.7500 - 131ms/epoch - 3ms/step
# Epoch 123/500
# 41/41 - 0s - loss: 0.6668 - accuracy: 0.7559 - val_loss: 0.7214 - val_accuracy: 0.7595 - 132ms/epoch - 3ms/step
# Epoch 124/500
# 41/41 - 0s - loss: 0.6407 - accuracy: 0.7628 - val_loss: 0.7070 - val_accuracy: 0.7511 - 131ms/epoch - 3ms/step
# Epoch 125/500
# 41/41 - 0s - loss: 0.6418 - accuracy: 0.7678 - val_loss: 0.6863 - val_accuracy: 0.7584 - 130ms/epoch - 3ms/step
# Epoch 126/500

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               8704
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 8)                 136
#
# =================================================================
# Total params: 27896 (108.97 KB)
# Trainable params: 27896 (108.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Epoch vs Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")

test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Training Accuracy: 97.70%
# Test Accuracy: 82.25%

# %%
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

if len(y_test.shape) == 1 or y_test.shape[1] == 1:
    y_true = y_test  
else:
    y_true = np.argmax(y_test, axis=1)  


conf_matrix = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

class_report = classification_report(y_true, y_pred_classes, target_names=[str(i) for i in range(len(np.unique(y_true)))])
print("Classification Report:")
print(class_report)
# Out:
# 6/6 [==============================] - 0s 888us/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.70      0.76        23
#            1       0.71      0.83      0.77        24
#            2       0.75      0.75      0.75        20
#            3       0.87      0.81      0.84        16
#            4       0.90      0.84      0.87        31
#            5       0.76      0.94      0.84        17
#            6       1.00      0.96      0.98        23
#            7       0.73      0.73      0.73        15
#
#     accuracy                           0.82       169
#    macro avg       0.82      0.82      0.82       169
# weighted avg       0.83      0.82      0.82       169

# %%
model.save('chi2_33_small.h5')
# Out:
# /home/ettexham/.local/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
