# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import seaborn as sns

# %%
data=pd.read_csv('ML_Data_48.csv')

# %%
data=data.drop(['Z_jerk_mean', 'X_jerk_mean', 'total_jerk_mean', 'Y_jerk_mean','X_jerk_mean','X_jerk_min', 'X_min', 'timestamp_range', 'Y_mean', 'X_mean', 'X_max','Z_mean', 'X_jerk_max', 'X_jerk_range', 'X_range'], axis=1)

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

# %%
x=data.drop(['label'], axis=1)
y=data['label']

# %%
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
x_train, x_t, y_train, y_t= train_test_split(x,y,test_size=0.3, random_state=42)
x_train.shape, x_t.shape
# Out:
# ((2614, 33), (1121, 33))

# %%
x_val, x_test, y_val, y_test= train_test_split(x_t, y_t, test_size=0.15, random_state=42)
x_val.shape, x_test.shape
# Out:
# ((952, 33), (169, 33))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import layers, models, optimizers
# Out:
# 2024-08-17 13:50:06.571868: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-17 13:50:06.573151: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-17 13:50:06.595766: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 13:50:06.595793: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 13:50:06.595811: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 13:50:06.600035: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-17 13:50:06.600462: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-17 13:50:07.139933: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Define a ResNet block
def resnet_block(input_tensor, units):
    x = layers.Dense(units, activation='relu')(input_tensor)
    x = layers.Dense(units)(x)
    x = layers.Add()([x, input_tensor])  # Add skip connection
    x = layers.ReLU()(x)
    return x

# Define the full ResNet model
def build_resnet_model(input_dim, hidden_dim, output_dim, num_blocks):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(hidden_dim, activation='relu')(inputs)
    
    for _ in range(num_blocks):
        x = resnet_block(x, hidden_dim)
    
    outputs = layers.Dense(output_dim, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    return model

# %%
input_dim = x_train.shape[1]
hidden_dim = 128
output_dim = len(y_train.unique())  # For classification
num_blocks = 3
learning_rate = 0.001
batch_size = 32
num_epochs = 100

# %%
model = build_resnet_model(input_dim, hidden_dim, output_dim, num_blocks)
model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history=model.fit(x_train, y_train, epochs=num_epochs, batch_size=batch_size, validation_data= (x_val, y_val))
# Out:
# Epoch 1/100
# 82/82 [==============================] - 1s 3ms/step - loss: 1.5234 - accuracy: 0.4373 - val_loss: 1.2835 - val_accuracy: 0.5263
# Epoch 2/100
# 82/82 [==============================] - 0s 2ms/step - loss: 1.1530 - accuracy: 0.5972 - val_loss: 1.0922 - val_accuracy: 0.5809
# Epoch 3/100
#  1/82 [..............................] - ETA: 0s - loss: 1.3324 - accuracy: 0.4375
# 2024-08-17 13:50:08.567516: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node model/re_lu_2/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-08-17 13:50:08.568724: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node model/re_lu_1/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-08-17 13:50:08.569288: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node model/re_lu/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-08-17 13:50:08.571806: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node model/re_lu/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-08-17 13:50:08.575190: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node model/re_lu/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-08-17 13:50:08.575303: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node model/re_lu/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-08-17 13:50:08.575527: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:596] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'model/re_lu/Relu' does not specify an operation
# 82/82 [==============================] - 0s 1ms/step - loss: 1.0128 - accuracy: 0.6419 - val_loss: 1.0288 - val_accuracy: 0.6155
# Epoch 4/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.8823 - accuracy: 0.6748 - val_loss: 0.9644 - val_accuracy: 0.6334
# Epoch 5/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.8547 - accuracy: 0.6886 - val_loss: 0.8813 - val_accuracy: 0.6618
# Epoch 6/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.7298 - accuracy: 0.7357 - val_loss: 0.8934 - val_accuracy: 0.6660
# Epoch 7/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.7452 - val_loss: 0.7977 - val_accuracy: 0.7101
# Epoch 8/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.5870 - accuracy: 0.7946 - val_loss: 0.9773 - val_accuracy: 0.6523
# Epoch 9/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.5528 - accuracy: 0.7938 - val_loss: 0.8421 - val_accuracy: 0.6975
# Epoch 10/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.8148 - val_loss: 0.7807 - val_accuracy: 0.7279
# Epoch 11/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.4868 - accuracy: 0.8183 - val_loss: 0.8134 - val_accuracy: 0.7342
# Epoch 12/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.4511 - accuracy: 0.8275 - val_loss: 0.7349 - val_accuracy: 0.7668
# Epoch 13/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.3941 - accuracy: 0.8520 - val_loss: 0.7889 - val_accuracy: 0.7332
# Epoch 14/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.3741 - accuracy: 0.8611 - val_loss: 0.8337 - val_accuracy: 0.7542
# Epoch 15/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.3312 - accuracy: 0.8741 - val_loss: 0.7948 - val_accuracy: 0.7616
# Epoch 16/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.3253 - accuracy: 0.8768 - val_loss: 0.8673 - val_accuracy: 0.7395
# Epoch 17/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.2978 - accuracy: 0.8936 - val_loss: 0.8486 - val_accuracy: 0.7626
# Epoch 18/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.8956 - val_loss: 0.8571 - val_accuracy: 0.7595
# Epoch 19/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.9112 - val_loss: 0.7717 - val_accuracy: 0.7794
# Epoch 20/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.9070 - val_loss: 0.8012 - val_accuracy: 0.7773
# Epoch 21/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.2690 - accuracy: 0.9013 - val_loss: 0.8061 - val_accuracy: 0.7637
# Epoch 22/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.9147 - val_loss: 0.9089 - val_accuracy: 0.7553
# Epoch 23/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.2068 - accuracy: 0.9288 - val_loss: 0.8418 - val_accuracy: 0.7700
# Epoch 24/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1638 - accuracy: 0.9357 - val_loss: 0.9305 - val_accuracy: 0.7679
# Epoch 25/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9419 - val_loss: 0.8933 - val_accuracy: 0.7878
# Epoch 26/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1884 - accuracy: 0.9254 - val_loss: 0.9348 - val_accuracy: 0.7605
# Epoch 27/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1811 - accuracy: 0.9331 - val_loss: 0.9943 - val_accuracy: 0.7511
# Epoch 28/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.2098 - accuracy: 0.9216 - val_loss: 0.8814 - val_accuracy: 0.7815
# Epoch 29/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1978 - accuracy: 0.9304 - val_loss: 0.9219 - val_accuracy: 0.7752
# Epoch 30/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9438 - val_loss: 0.9389 - val_accuracy: 0.7626
# Epoch 31/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.2038 - accuracy: 0.9308 - val_loss: 1.0126 - val_accuracy: 0.7679
# Epoch 32/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.9331 - val_loss: 0.8866 - val_accuracy: 0.7889
# Epoch 33/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1206 - accuracy: 0.9572 - val_loss: 0.9863 - val_accuracy: 0.7721
# Epoch 34/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1402 - accuracy: 0.9453 - val_loss: 1.0438 - val_accuracy: 0.7815
# Epoch 35/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 0.9545 - val_loss: 0.9472 - val_accuracy: 0.7941
# Epoch 36/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9686 - val_loss: 1.0258 - val_accuracy: 0.7689
# Epoch 37/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.9633 - val_loss: 1.1193 - val_accuracy: 0.7668
# Epoch 38/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9686 - val_loss: 1.1278 - val_accuracy: 0.7710
# Epoch 39/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1724 - accuracy: 0.9407 - val_loss: 1.0399 - val_accuracy: 0.7584
# Epoch 40/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9549 - val_loss: 1.1684 - val_accuracy: 0.7479
# Epoch 41/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1346 - accuracy: 0.9518 - val_loss: 1.0930 - val_accuracy: 0.7584
# Epoch 42/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1477 - accuracy: 0.9484 - val_loss: 0.9304 - val_accuracy: 0.7878
# Epoch 43/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1291 - accuracy: 0.9560 - val_loss: 0.9339 - val_accuracy: 0.7805
# Epoch 44/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0824 - accuracy: 0.9686 - val_loss: 1.0327 - val_accuracy: 0.7815
# Epoch 45/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0844 - accuracy: 0.9694 - val_loss: 1.0850 - val_accuracy: 0.7857
# Epoch 46/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1202 - accuracy: 0.9591 - val_loss: 1.0225 - val_accuracy: 0.7626
# Epoch 47/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.9652 - val_loss: 1.1005 - val_accuracy: 0.7847
# Epoch 48/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1642 - accuracy: 0.9491 - val_loss: 1.0674 - val_accuracy: 0.7595
# Epoch 49/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0932 - accuracy: 0.9675 - val_loss: 1.1119 - val_accuracy: 0.7742
# Epoch 50/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0946 - accuracy: 0.9660 - val_loss: 1.0620 - val_accuracy: 0.7836
# Epoch 51/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1293 - accuracy: 0.9526 - val_loss: 1.0567 - val_accuracy: 0.7689
# Epoch 52/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0836 - accuracy: 0.9686 - val_loss: 1.0647 - val_accuracy: 0.7658
# Epoch 53/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1020 - accuracy: 0.9671 - val_loss: 1.0485 - val_accuracy: 0.7773
# Epoch 54/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9537 - val_loss: 1.0224 - val_accuracy: 0.7868
# Epoch 55/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 0.9717 - val_loss: 1.1295 - val_accuracy: 0.7815
# Epoch 56/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1096 - accuracy: 0.9617 - val_loss: 0.9481 - val_accuracy: 0.7773
# Epoch 57/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 0.9805 - val_loss: 1.0890 - val_accuracy: 0.7805
# Epoch 58/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1023 - accuracy: 0.9633 - val_loss: 0.9993 - val_accuracy: 0.7805
# Epoch 59/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0620 - accuracy: 0.9774 - val_loss: 1.0633 - val_accuracy: 0.7815
# Epoch 60/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0778 - accuracy: 0.9736 - val_loss: 1.0393 - val_accuracy: 0.8057
# Epoch 61/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0536 - accuracy: 0.9770 - val_loss: 1.0725 - val_accuracy: 0.7868
# Epoch 62/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.9633 - val_loss: 0.9933 - val_accuracy: 0.7857
# Epoch 63/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0854 - accuracy: 0.9679 - val_loss: 1.1155 - val_accuracy: 0.7815
# Epoch 64/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1007 - accuracy: 0.9625 - val_loss: 1.1954 - val_accuracy: 0.7626
# Epoch 65/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.9637 - val_loss: 1.0854 - val_accuracy: 0.7742
# Epoch 66/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0838 - accuracy: 0.9686 - val_loss: 1.0600 - val_accuracy: 0.7920
# Epoch 67/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1383 - accuracy: 0.9560 - val_loss: 1.1385 - val_accuracy: 0.7794
# Epoch 68/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9640 - val_loss: 1.2496 - val_accuracy: 0.7416
# Epoch 69/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 0.9751 - val_loss: 1.1185 - val_accuracy: 0.7752
# Epoch 70/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 0.9874 - val_loss: 1.2434 - val_accuracy: 0.7700
# Epoch 71/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 0.9870 - val_loss: 1.2865 - val_accuracy: 0.7742
# Epoch 72/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0514 - accuracy: 0.9824 - val_loss: 1.3818 - val_accuracy: 0.7574
# Epoch 73/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1027 - accuracy: 0.9617 - val_loss: 1.2140 - val_accuracy: 0.7563
# Epoch 74/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.1149 - accuracy: 0.9583 - val_loss: 1.0902 - val_accuracy: 0.7742
# Epoch 75/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0664 - accuracy: 0.9778 - val_loss: 1.1867 - val_accuracy: 0.7805
# Epoch 76/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0596 - accuracy: 0.9847 - val_loss: 1.2366 - val_accuracy: 0.7679
# Epoch 77/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1258 - accuracy: 0.9614 - val_loss: 1.0748 - val_accuracy: 0.7983
# Epoch 78/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1400 - accuracy: 0.9594 - val_loss: 1.1224 - val_accuracy: 0.7668
# Epoch 79/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0813 - accuracy: 0.9713 - val_loss: 1.0285 - val_accuracy: 0.7826
# Epoch 80/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0616 - accuracy: 0.9790 - val_loss: 1.2616 - val_accuracy: 0.7584
# Epoch 81/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 0.9740 - val_loss: 1.1134 - val_accuracy: 0.7815
# Epoch 82/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9862 - val_loss: 1.1675 - val_accuracy: 0.7763
# Epoch 83/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 0.9855 - val_loss: 1.1388 - val_accuracy: 0.7826
# Epoch 84/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0657 - accuracy: 0.9759 - val_loss: 1.1471 - val_accuracy: 0.7647
# Epoch 85/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0712 - accuracy: 0.9748 - val_loss: 1.1333 - val_accuracy: 0.7899
# Epoch 86/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0473 - accuracy: 0.9809 - val_loss: 1.1536 - val_accuracy: 0.7826
# Epoch 87/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0450 - accuracy: 0.9813 - val_loss: 1.2387 - val_accuracy: 0.7857
# Epoch 88/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0483 - accuracy: 0.9816 - val_loss: 1.2625 - val_accuracy: 0.7920
# Epoch 89/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0418 - accuracy: 0.9843 - val_loss: 1.2893 - val_accuracy: 0.7784
# Epoch 90/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0656 - accuracy: 0.9759 - val_loss: 1.2202 - val_accuracy: 0.7836
# Epoch 91/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0575 - accuracy: 0.9778 - val_loss: 1.1890 - val_accuracy: 0.7941
# Epoch 92/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.9610 - val_loss: 1.2214 - val_accuracy: 0.7679
# Epoch 93/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0644 - accuracy: 0.9744 - val_loss: 1.1975 - val_accuracy: 0.7805
# Epoch 94/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0970 - accuracy: 0.9717 - val_loss: 1.1814 - val_accuracy: 0.7637
# Epoch 95/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0865 - accuracy: 0.9694 - val_loss: 1.1050 - val_accuracy: 0.7668
# Epoch 96/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0474 - accuracy: 0.9790 - val_loss: 1.1263 - val_accuracy: 0.7962
# Epoch 97/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0709 - accuracy: 0.9782 - val_loss: 1.1578 - val_accuracy: 0.7920
# Epoch 98/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0873 - accuracy: 0.9679 - val_loss: 1.2594 - val_accuracy: 0.7700
# Epoch 99/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 0.9744 - val_loss: 1.1367 - val_accuracy: 0.7784
# Epoch 100/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.0871 - accuracy: 0.9713 - val_loss: 1.1727 - val_accuracy: 0.7658

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 33)]                 0         []
#
#  dense (Dense)               (None, 128)                  4352      ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  16512     ['dense_1[0][0]']
#
#  add (Add)                   (None, 128)                  0         ['dense_2[0][0]',
#                                                                      'dense[0][0]']
#
#  re_lu (ReLU)                (None, 128)                  0         ['add[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  16512     ['re_lu[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  16512     ['dense_3[0][0]']
#
#  add_1 (Add)                 (None, 128)                  0         ['dense_4[0][0]',
#                                                                      're_lu[0][0]']
#
#  re_lu_1 (ReLU)              (None, 128)                  0         ['add_1[0][0]']
#
#  dense_5 (Dense)             (None, 128)                  16512     ['re_lu_1[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  16512     ['dense_5[0][0]']
#
#  add_2 (Add)                 (None, 128)                  0         ['dense_6[0][0]',
#                                                                      're_lu_1[0][0]']
#
#  re_lu_2 (ReLU)              (None, 128)                  0         ['add_2[0][0]']
#
#  dense_7 (Dense)             (None, 8)                    1032      ['re_lu_2[0][0]']
#
# ==================================================================================================
# Total params: 104456 (408.03 KB)
# Trainable params: 104456 (408.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Epoch vs Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")

test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Training Accuracy: 97.67%
# Test Accuracy: 71.60%

# %%
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

if len(y_test.shape) == 1 or y_test.shape[1] == 1:
    y_true = y_test  
else:
    y_true = np.argmax(y_test, axis=1)  


conf_matrix = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

class_report = classification_report(y_true, y_pred_classes, target_names=[str(i) for i in range(len(np.unique(y_true)))])
print("Classification Report:")
print(class_report)
# Out:
# 6/6 [==============================] - 0s 969us/step
# 2024-08-17 13:50:20.833700: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node model/re_lu_2/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-08-17 13:50:20.834962: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node model/re_lu_1/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-08-17 13:50:20.835595: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node model/re_lu/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-08-17 13:50:20.836938: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node model/re_lu/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-08-17 13:50:20.839331: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node model/re_lu/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-08-17 13:50:20.839421: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node model/re_lu/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-08-17 13:50:20.839582: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:596] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'model/re_lu/Relu' does not specify an operation
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.48      0.59        23
#            1       0.65      0.83      0.73        24
#            2       0.65      0.65      0.65        20
#            3       0.71      0.62      0.67        16
#            4       0.68      0.68      0.68        31
#            5       0.62      0.88      0.73        17
#            6       1.00      0.96      0.98        23
#            7       0.69      0.60      0.64        15
#
#     accuracy                           0.72       169
#    macro avg       0.72      0.71      0.71       169
# weighted avg       0.73      0.72      0.71       169
