# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('combined_features_data.csv')

# %%
data['label']=data['label'].astype('int')

# %%
data.reset_index(inplace=True)
data.drop(['index'], axis=1, inplace=True)

# %%
data
# Out:
#       label     X_min     X_max   X_range    X_mean     X_rms     X_std  \
# 0         3 -1.004375  0.138634  1.143009 -0.271257  0.367041  0.248950
# 1         3 -0.990767  0.127101  1.117868 -0.423896  0.505179  0.276519
# 2         3 -0.720209  0.214299  0.934508 -0.271104  0.341752  0.209499
# 3         3 -0.496083  0.153754  0.649837 -0.224294  0.278918  0.167294
# 4         3 -0.861475  0.202574  1.064049 -0.318783  0.396607  0.237407
# ...     ...       ...       ...       ...       ...       ...       ...
# 3730      5 -0.834887  1.088238  1.923125 -0.198314  0.477376  0.437464
# 3731      5 -1.592273  0.800989  2.393262 -0.223964  0.589055  0.549660
# 3732      5 -1.145478  0.834240  1.979718 -0.288274  0.501753  0.413404
# 3733      5 -0.828272  0.844807  1.673079 -0.121973  0.453033  0.439700
# 3734      5 -1.113732  0.943032  2.056763 -0.108171  0.509870  0.502692
#
#          Y_min     Y_max   Y_range  ...  Z_jerk_mean  Z_jerk_rms  Z_jerk_std  \
# ...

# %%
data = data[~data['label'].isin([1, 3, 5])]

# %%
label_mapping = {2: 1, 4: 2, 6: 3, 7: 4}

# %%
data['label'] = data['label'].replace(label_mapping)
# Out:
# /tmp/ipykernel_10529/3664380128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label'] = data['label'].replace(label_mapping)

# %%
data['label'].value_counts()
# Out:
# 2    591
# 3    573
# 1    501
# 4    452
# 0    436
# Name: label, dtype: int64

# %%
data.to_csv('/home/ettexham/Desktop/Thesis/Accelerometer Data/DataSet/Clockwise_Notebooks/ML_Data_CW.csv', index=False)
