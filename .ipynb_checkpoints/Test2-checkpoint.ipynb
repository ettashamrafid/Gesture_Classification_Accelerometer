# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train_data.csv")

# %%
df
# Out:
#            time  ax (m/s^2)  ay (m/s^2)  az (m/s^2)  aT (m/s^2)
# 0      0.002137     -0.6351     -0.2741      1.4341       1.592
# 1      0.002693     -0.5610     -0.2834      1.2026       1.357
# 2      0.003030     -0.3700     -0.2337      1.0291       1.118
# 3      0.009200     -0.1476     -0.1918      0.8321       0.867
# 4      0.014901      0.0449     -0.1571      0.6357       0.656
# ...         ...         ...         ...         ...         ...
# 5343  26.557032     -0.1207     -0.1780      0.1284       0.250
# 5344  26.557331     -0.2198     -0.2826      0.0418       0.360
# 5345  26.562499     -0.2012     -0.2011     -0.0487       0.289
# 5346  26.571826     -0.1466     -0.0539     -0.0387       0.161
# 5347  26.572368     -0.0803      0.0491     -0.0096       0.095
#
# [5348 rows x 5 columns]

# %%
df.columns[0]
# Out:
# 'time'

# %%
df.rename(columns={'ax (m/s^2)': 'x_data'}, inplace=True)
df.rename(columns={'ay (m/s^2)': 'y_data'}, inplace=True)
df.rename(columns={'az (m/s^2)': 'z_data'}, inplace=True)

# %%
df.columns
# Out:
# Index(['time', 'x_data', 'y_data', 'z_data', 'aT (m/s^2)'], dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['time'],df['x_data'], label='X-axis acceleration')
plt.plot(df['time'],df['y_data'], label='Y-axis acceleration')
plt.plot(df['time'],df['z_data'], label='Z-axis acceleration')
plt.title('Accelerometer Data')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
df['time']
# Out:
# 0        0.002137
# 1        0.002693
# 2        0.003030
# 3        0.009200
# 4        0.014901
#           ...
# 5343    26.557032
# 5344    26.557331
# 5345    26.562499
# 5346    26.571826
# 5347    26.572368
# Name: time, Length: 5348, dtype: float64

# %%
df['time'][850]
#from 0 t0 4s
# Out:
# 4.218887

# %%
df1 = df.iloc[:850]
#from 0 t0 4s

# %%
df['time'][2400]
# Out:
# 11.923019

# %%
df2 = df.iloc[1400:2400]
#from 7 t0 12s

# %%
df['time'][3200]
# Out:
# 15.910572

# %%
df3 = df.iloc[2650:3200]
##from 13 t0 16s

# %%
df['time'][3600]
# Out:
# 17.888889

# %%
df4 = df.iloc[3200:3600]
##from 16 t0 18s

# %%
df['time'][4450]
# Out:
# 22.11367

# %%
df5 = df.iloc[3600:4450]
##from 18 t0 22s

# %%
df['time'][5050]
# Out:
# 25.097107

# %%
df6 = df.iloc[4450:5050]
##from 22 t0 25s

# %%
def moving_average_filter(df, window_size):
    """
    Apply a moving average filter to the input DataFrame.

    Parameters:
        df (DataFrame): The input DataFrame.
        window_size (int): The size of the moving window.

    Returns:
        DataFrame: The filtered DataFrame.
    """
    # Apply the filter using rolling mean
    filtered_df = df.rolling(window=window_size, min_periods=1).mean()

    return filtered_df

window_size = 35
dff1 = moving_average_filter(df1[['x_data','y_data','z_data']], window_size)

# Print the results
print("Original DataFrame:")
print(df1)
print("\nFiltered DataFrame:")
print(dff1)
# Out:
# Original DataFrame:
#          time  x_data  y_data  z_data  aT (m/s^2)
# 0    0.002137 -0.6351 -0.2741  1.4341       1.592
# 1    0.002693 -0.5610 -0.2834  1.2026       1.357
# 2    0.003030 -0.3700 -0.2337  1.0291       1.118
# 3    0.009200 -0.1476 -0.1918  0.8321       0.867
# 4    0.014901  0.0449 -0.1571  0.6357       0.656
# ..        ...     ...     ...     ...         ...
# 845  4.194250  0.0643  0.0285  0.0704       0.100
# 846  4.199527  0.0682  0.0307  0.0745       0.106
# 847  4.204370  0.0623  0.0041  0.0690       0.093
# 848  4.210089  0.0326 -0.0131  0.0731       0.081
# 849  4.214399 -0.0159 -0.0161  0.0677       0.071
#
# [850 rows x 5 columns]
#
# Filtered DataFrame:
#        x_data    y_data    z_data
# 0   -0.635100 -0.274100  1.434100
# 1   -0.598050 -0.278750  1.318350
# 2   -0.522033 -0.263733  1.221933
# 3   -0.428425 -0.245750  1.124475
# 4   -0.333760 -0.228020  1.026720
# ..        ...       ...       ...
# 845  0.013360  0.006389  0.004974
# ...

# %%
dff1['time']=df1['time']

# %%
dff1
# Out:
#        x_data    y_data    z_data      time
# 0   -0.635100 -0.274100  1.434100  0.002137
# 1   -0.598050 -0.278750  1.318350  0.002693
# 2   -0.522033 -0.263733  1.221933  0.003030
# 3   -0.428425 -0.245750  1.124475  0.009200
# 4   -0.333760 -0.228020  1.026720  0.014901
# ..        ...       ...       ...       ...
# 845  0.013360  0.006389  0.004974  4.194250
# 846  0.014977  0.006463  0.005597  4.199527
# 847  0.015737  0.006083  0.006889  4.204370
# 848  0.015643  0.005386  0.009660  4.210089
# 849  0.013623  0.004774  0.013766  4.214399
#
# [850 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(dff1['time'],dff1['x_data'], label='X-axis acceleration')
plt.title('Accelerometer Data Moving average 110')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1['time'],df1['x_data'], label='X-axis acceleration')
plt.title('Accelerometer Data jeta dise oidai')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df1['time'],df1['x_data'], label='x-axis acceleration')
plt.plot(df1['time'],df1['y_data'], label='y-axis acceleration')
plt.plot(df1['time'],df1['z_data'], label='z-axis acceleration')
plt.title('jeda dise oidai')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(dff1['time'],dff1['x_data'], label='x-axis acceleration')
plt.plot(dff1['time'],dff1['y_data'], label='y-axis acceleration')
plt.plot(dff1['time'],dff1['z_data'], label='z-axis acceleration')
plt.title('Accelerometer Data Moving average 35')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
dff=df

# %%
dffbaal = moving_average_filter(dff[['x_data','y_data','z_data']], window_size)
dffbaal['time']=dff['time']

# %%
plt.figure(figsize=(10, 6))
plt.plot(dffbaal['time'],dffbaal['x_data'], label='x-axis acceleration')
plt.plot(dffbaal['time'],dffbaal['y_data'], label='y-axis acceleration')
plt.plot(dffbaal['time'],dffbaal['z_data'], label='z-axis acceleration')
plt.title('Accelerometer Data Moving average 35 whole data')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
dff=df.drop(['time','aT (m/s^2)'],axis=1)

# %%
fft_result = {}
for col in dff.columns:
    fft_values = np.fft.fft(dff[col])
    fft_freq = np.fft.fftfreq(len(dff), d=1/505)  # Compute the frequencies
    fft_magnitude = np.abs(fft_values) / len(dff)  # Compute the magnitudes
    fft_result[col] = (fft_freq, fft_magnitude)

# Plot the results
for col, (freq, mag) in fft_result.items():
    plt.plot(abs(freq), mag, label=col)

plt.title('FFT Results')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
dff
# Out:
#       x_data  y_data  z_data
# 0    -0.6351 -0.2741  1.4341
# 1    -0.5610 -0.2834  1.2026
# 2    -0.3700 -0.2337  1.0291
# 3    -0.1476 -0.1918  0.8321
# 4     0.0449 -0.1571  0.6357
# ...      ...     ...     ...
# 5343 -0.1207 -0.1780  0.1284
# 5344 -0.2198 -0.2826  0.0418
# 5345 -0.2012 -0.2011 -0.0487
# 5346 -0.1466 -0.0539 -0.0387
# 5347 -0.0803  0.0491 -0.0096
#
# [5348 rows x 3 columns]

# %%
fft_result
# Out:
# {'x_data': (array([ 0.        ,  0.09442782,  0.18885565, ..., -0.28328347,
#          -0.18885565, -0.09442782]),
#   array([0.03672145, 0.03600844, 0.03903176, ..., 0.05267613, 0.03903176,
#          0.03600844])),
#  'y_data': (array([ 0.        ,  0.09442782,  0.18885565, ..., -0.28328347,
#          -0.18885565, -0.09442782]),
#   array([1.04993371, 0.1912719 , 0.02072387, ..., 0.22572751, 0.02072387,
#          0.1912719 ])),
#  'z_data': (array([ 0.        ,  0.09442782,  0.18885565, ..., -0.28328347,
#          -0.18885565, -0.09442782]),
#   array([0.1325492 , 0.06920651, 0.03239331, ..., 0.00146432, 0.03239331,
#          0.06920651]))}

# %%
fft_result.keys()
# Out:
# dict_keys(['x_data', 'y_data', 'z_data'])

# %%
x_freq, x_magnitude = fft_result['x_data']

# Plot the frequency and magnitude
plt.plot(abs(x_freq[:500]), x_magnitude[:500])
plt.title('FFT Results for x_data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %%
y_freq, y_magnitude = fft_result['y_data']

plt.plot(abs(y_freq[:500]), y_magnitude[:500])
plt.title('FFT Results for y_data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %%
z_freq, z_magnitude = fft_result['z_data']


# Plot the frequency and magnitude
plt.plot(abs(z_freq[:500]), z_magnitude[:500])

plt.title('FFT Results for z_data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %%
from scipy.signal import butter, filtfilt
sampling_rate=505

def low_pass_filter(data, cutoff_freq, fs):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff_freq / nyquist
    b, a = butter(4, normal_cutoff, btype='low', analog=False)
    filtered_data = filtfilt(b, a, data)
    return filtered_data

# %%
cutoff_frequency = 5  # Specify your cutoff frequency here
filtered_datax = low_pass_filter(dff['x_data'], cutoff_frequency, sampling_rate)
filtered_datay = low_pass_filter(dff['y_data'], cutoff_frequency, sampling_rate)
filtered_dataz = low_pass_filter(dff['z_data'], cutoff_frequency, sampling_rate)

# %%
type(filtered_datax)
# Out:
# numpy.ndarray

# %%
data = {'x_data': filtered_datax , 'y_data': filtered_datay, 'z_data': filtered_dataz }

filtered_datam=pd.DataFrame(data)

# %%
filtered_datam['time']=df['time']

# %%
filtered_datam
# Out:
#         x_data    y_data    z_data       time
# 0    -0.627399 -0.278929  1.528148   0.002137
# 1    -0.600594 -0.267366  1.456960   0.002693
# 2    -0.573868 -0.255868  1.386241   0.003030
# 3    -0.547266 -0.244452  1.316102   0.009200
# 4    -0.520832 -0.233136  1.246655   0.014901
# ...        ...       ...       ...        ...
# 5343 -0.044444 -0.053829 -0.026790  26.557032
# 5344 -0.044581 -0.053816 -0.026795  26.557331
# 5345 -0.044696 -0.053804 -0.026799  26.562499
# 5346 -0.044789 -0.053794 -0.026800  26.571826
# 5347 -0.044865 -0.053785 -0.026801  26.572368
#
# [5348 rows x 4 columns]

# %%
plt.figure(figsize=(12, 8))
plt.plot(filtered_datam['x_data'], label='x-axis acceleration')
plt.plot(filtered_datam['y_data'], label='x-axis acceleration')
plt.plot(filtered_datam['z_data'], label='x-axis acceleration')
plt.title('Accelerometer Data low pass 5hz cutoff')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
df1.shape
# Out:
# (850, 5)

# %%
df2.shape
# Out:
# (1000, 5)

# %%
df3.shape
# Out:
# (550, 5)

# %%
df4.shape
# Out:
# (400, 5)

# %%
df5.shape
# Out:
# (850, 5)

# %%
df6.shape
# Out:
# (600, 5)

# %%
plt.figure(figsize=(12, 8))
plt.plot(filtered_datam['x_data'], label='x-axis acceleration')
plt.plot(filtered_datam['y_data'], label='x-axis acceleration')
plt.plot(filtered_datam['z_data'], label='x-axis acceleration')
plt.title('Accelerometer Data low pass 5hz cutoff')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
dff1 = filtered_datam.iloc[200:700]

# %%
dff2 = filtered_datam.iloc[1450:2050]

# %%
dff3 = filtered_datam.iloc[2200:2750]

# %%
dff4 = filtered_datam.iloc[3000:3600]

# %%
dff5 = filtered_datam.iloc[3600:4250]

# %%
dff6 = filtered_datam.iloc[4400:4950]

# %%
def calculate_statistics(df, column_name):
    column_data = df[column_name]
    stats_dict = {}
    
    stats_dict[column_name + '_min'] = np.min(column_data)
    
    stats_dict[column_name + '_max'] = np.max(column_data)

    stats_dict[column_name + '_range'] = np.ptp(column_data)

    # Calculate average
    stats_dict[column_name + '_avg'] = np.mean(column_data)

    # Calculate standard deviation
    stats_dict[column_name + '_std'] = np.std(column_data)

    # Calculate variance
    stats_dict[column_name + '_var'] = np.var(column_data)

    # Calculate root mean square (RMS)
    stats_dict[column_name + '_rms'] = np.sqrt(np.mean(column_data**2))

    return stats_dict

# %%
def det_time(df, column_name):
    return np.max(df[column_name])- np.min(df[column_name])

# %%
feature=pd.DataFrame()

dct_lst=[dff1,dff2,dff3,dff4,dff5,dff6]
for i in dct_lst:
    lst=['x_data', 'y_data', 'z_data', 'x_jerk', 'y_jerk', 'z_jerk', 'total', 'total_jerk']
    i['total'] = np.sqrt(i['x_data']**2 + i['y_data']**2 + i['z_data']**2)
    i['x_jerk'] = (i['x_data'] - i['x_data'].shift(1)) / (i['time'] - i['time'].shift(1))
    i['y_jerk'] = (i['y_data'] - i['y_data'].shift(1)) / (i['time'] - i['time'].shift(1))
    i['z_jerk'] = (i['z_data'] - i['z_data'].shift(1)) / (i['time'] - i['time'].shift(1))
    i['total_jerk'] = (i['total'] - i['total'].shift(1)) / (i['time'] - i['time'].shift(1))
    feature_dct={}
    feature_dct['time']=det_time(i, 'time')
    for j in lst:
        temp_dict= calculate_statistics(i, j)
        feature_dct.update(temp_dict)
    feature=feature.append(feature_dct, ignore_index=True)
# Out:
# /tmp/ipykernel_15708/4173344296.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['total'] = np.sqrt(i['x_data']**2 + i['y_data']**2 + i['z_data']**2)
# /tmp/ipykernel_15708/4173344296.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['x_jerk'] = (i['x_data'] - i['x_data'].shift(1)) / (i['time'] - i['time'].shift(1))
# /tmp/ipykernel_15708/4173344296.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
feature
# Out:
#        time  x_data_min  x_data_max  x_data_range  x_data_avg  x_data_std  \
# 0  2.489733   -4.652963    4.014947      8.667910   -0.430712    2.010523
# 1  2.976600   -4.022874    4.499274      8.522148    0.026498    1.726603
# 2  2.729757   -4.294207    3.410914      7.705121   -0.038156    1.701874
# 3  2.973160   -4.817794    4.606589      9.424383    0.022327    1.834499
# 4  3.227398   -5.512716    5.390217     10.902933   -0.017891    2.002318
# 5  2.729445   -4.344222    4.014463      8.358685    0.009938    1.690458
#
#    x_data_var  x_data_rms  y_data_min  y_data_max  ...  total_std  total_var  \
# 0    4.042203    2.056141   -5.880917    0.479086  ...   3.190969  10.182282
# 1    2.981159    1.726807   -7.627635    0.169206  ...   3.181992  10.125074
# 2    2.896374    1.702301   -7.251263    0.282675  ...   3.011733   9.070534
# 3    3.365385    1.834634   -8.866156    0.406658  ...   3.359874  11.288755
# ...
