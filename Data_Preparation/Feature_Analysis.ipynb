# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_classif

# %%
# Load your dataset
# Assume the dataset is in a CSV file
df = pd.read_csv('ML_Data.csv')

# %%
# Calculate the correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap='coolwarm')
plt.show()

# %%
# Identify highly correlated features
threshold = 0.8
high_corr_var = np.where(np.abs(corr_matrix) > threshold)
high_corr_var = [(corr_matrix.index[x], corr_matrix.columns[y]) for x, y in zip(*high_corr_var) if x != y and x < y]

print("Highly correlated features (threshold > 0.8):")
for pair in high_corr_var:
    print(pair)
# Out:
# Highly correlated features (threshold > 0.8):
# ('X_max', 'X_range')
# ('X_max', 'X_std')
# ('X_range', 'X_std')
# ('X_range', 'X_jerk_max')
# ('X_range', 'X_jerk_range')
# ('X_range', 'X_jerk_rms')
# ('X_range', 'X_jerk_std')
# ('X_std', 'X_jerk_range')
# ('X_std', 'X_jerk_rms')
# ('X_std', 'X_jerk_std')
# ('Y_min', 'Y_range')
# ('Y_min', 'Y_rms')
# ('Y_min', 'Y_std')
# ('Y_min', 'Z_min')
# ('Y_min', 'Z_range')
# ('Y_min', 'Z_std')
# ('Y_min', 'Y_jerk_min')
# ('Y_min', 'Y_jerk_max')
# ('Y_min', 'Y_jerk_range')
# ('Y_min', 'Y_jerk_rms')
# ('Y_min', 'Y_jerk_std')
# ('Y_min', 'Z_jerk_max')
# ('Y_min', 'Z_jerk_range')
# ('Y_min', 'Z_jerk_rms')
# ('Y_min', 'Z_jerk_std')
# ('Y_min', 'total_jerk_max')
# ('Y_min', 'total_jerk_range')
# ('Y_min', 'total_jerk_rms')
# ('Y_min', 'total_jerk_std')
# ('Y_range', 'Y_rms')
# ('Y_range', 'Y_std')
# ('Y_range', 'Z_min')
# ('Y_range', 'Z_range')
# ('Y_range', 'Z_std')
# ('Y_range', 'Y_jerk_min')
# ('Y_range', 'Y_jerk_max')
# ('Y_range', 'Y_jerk_range')
# ('Y_range', 'Y_jerk_rms')
# ('Y_range', 'Y_jerk_std')
# ('Y_range', 'Z_jerk_max')
# ('Y_range', 'Z_jerk_range')
# ('Y_range', 'Z_jerk_rms')
# ('Y_range', 'Z_jerk_std')
# ('Y_range', 'total_jerk_min')
# ('Y_range', 'total_jerk_max')
# ('Y_range', 'total_jerk_range')
# ('Y_range', 'total_jerk_rms')
# ('Y_range', 'total_jerk_std')
# ('Y_rms', 'Y_std')
# ('Y_rms', 'Z_range')
# ('Y_rms', 'Z_std')
# ('Y_rms', 'Y_jerk_min')
# ('Y_rms', 'Y_jerk_range')
# ('Y_rms', 'Y_jerk_rms')
# ('Y_rms', 'Y_jerk_std')
# ('Y_rms', 'Z_jerk_rms')
# ('Y_rms', 'Z_jerk_std')
# ('Y_rms', 'total_jerk_rms')
# ('Y_rms', 'total_jerk_std')
# ('Y_std', 'Z_min')
# ('Y_std', 'Z_range')
# ('Y_std', 'Z_std')
# ('Y_std', 'Y_jerk_min')
# ('Y_std', 'Y_jerk_max')
# ('Y_std', 'Y_jerk_range')
# ('Y_std', 'Y_jerk_rms')
# ('Y_std', 'Y_jerk_std')
# ('Y_std', 'Z_jerk_max')
# ('Y_std', 'Z_jerk_range')
# ('Y_std', 'Z_jerk_rms')
# ('Y_std', 'Z_jerk_std')
# ('Y_std', 'total_jerk_max')
# ('Y_std', 'total_jerk_range')
# ('Y_std', 'total_jerk_rms')
# ('Y_std', 'total_jerk_std')
# ('Z_min', 'Z_range')
# ('Z_min', 'Z_std')
# ('Z_min', 'Y_jerk_min')
# ('Z_min', 'Y_jerk_range')
# ('Z_min', 'Y_jerk_rms')
# ('Z_min', 'Y_jerk_std')
# ('Z_min', 'Z_jerk_max')
# ('Z_min', 'Z_jerk_range')
# ('Z_min', 'Z_jerk_rms')
# ('Z_min', 'Z_jerk_std')
# ('Z_min', 'total_jerk_range')
# ('Z_min', 'total_jerk_rms')
# ('Z_min', 'total_jerk_std')
# ('Z_max', 'Z_range')
# ('Z_max', 'Z_rms')
# ('Z_max', 'Z_std')
# ('Z_max', 'Z_jerk_min')
# ('Z_max', 'Z_jerk_max')
# ('Z_max', 'Z_jerk_range')
# ('Z_max', 'Z_jerk_rms')
# ('Z_max', 'Z_jerk_std')
# ('Z_max', 'total_jerk_max')
# ('Z_max', 'total_jerk_range')
# ('Z_max', 'total_jerk_rms')
# ('Z_max', 'total_jerk_std')
# ('Z_range', 'Z_rms')
# ('Z_range', 'Z_std')
# ('Z_range', 'Y_jerk_min')
# ('Z_range', 'Y_jerk_range')
# ('Z_range', 'Y_jerk_rms')
# ('Z_range', 'Y_jerk_std')
# ('Z_range', 'Z_jerk_min')
# ('Z_range', 'Z_jerk_max')
# ('Z_range', 'Z_jerk_range')
# ('Z_range', 'Z_jerk_rms')
# ('Z_range', 'Z_jerk_std')
# ('Z_range', 'total_jerk_min')
# ('Z_range', 'total_jerk_max')
# ('Z_range', 'total_jerk_range')
# ('Z_range', 'total_jerk_rms')
# ('Z_range', 'total_jerk_std')
# ('Z_rms', 'Z_std')
# ('Z_rms', 'Y_jerk_rms')
# ('Z_rms', 'Y_jerk_std')
# ('Z_rms', 'Z_jerk_max')
# ('Z_rms', 'Z_jerk_range')
# ('Z_rms', 'Z_jerk_rms')
# ('Z_rms', 'Z_jerk_std')
# ('Z_rms', 'total_jerk_rms')
# ('Z_rms', 'total_jerk_std')
# ('Z_std', 'Y_jerk_min')
# ('Z_std', 'Y_jerk_range')
# ('Z_std', 'Y_jerk_rms')
# ('Z_std', 'Y_jerk_std')
# ('Z_std', 'Z_jerk_min')
# ('Z_std', 'Z_jerk_max')
# ('Z_std', 'Z_jerk_range')
# ('Z_std', 'Z_jerk_rms')
# ('Z_std', 'Z_jerk_std')
# ('Z_std', 'total_jerk_min')
# ('Z_std', 'total_jerk_max')
# ('Z_std', 'total_jerk_range')
# ('Z_std', 'total_jerk_rms')
# ('Z_std', 'total_jerk_std')
# ('X_jerk_min', 'X_jerk_range')
# ('X_jerk_min', 'X_jerk_rms')
# ('X_jerk_min', 'X_jerk_std')
# ('X_jerk_max', 'X_jerk_range')
# ('X_jerk_max', 'X_jerk_rms')
# ('X_jerk_max', 'X_jerk_std')
# ('X_jerk_range', 'X_jerk_rms')
# ('X_jerk_range', 'X_jerk_std')
# ('X_jerk_rms', 'X_jerk_std')
# ('Y_jerk_min', 'Y_jerk_max')
# ('Y_jerk_min', 'Y_jerk_range')
# ('Y_jerk_min', 'Y_jerk_rms')
# ('Y_jerk_min', 'Y_jerk_std')
# ('Y_jerk_min', 'Z_jerk_max')
# ('Y_jerk_min', 'Z_jerk_range')
# ('Y_jerk_min', 'Z_jerk_rms')
# ('Y_jerk_min', 'Z_jerk_std')
# ('Y_jerk_min', 'total_jerk_min')
# ('Y_jerk_min', 'total_jerk_max')
# ('Y_jerk_min', 'total_jerk_range')
# ('Y_jerk_min', 'total_jerk_rms')
# ('Y_jerk_min', 'total_jerk_std')
# ('Y_jerk_max', 'Y_jerk_range')
# ('Y_jerk_max', 'Y_jerk_rms')
# ('Y_jerk_max', 'Y_jerk_std')
# ('Y_jerk_max', 'Z_jerk_range')
# ('Y_jerk_max', 'Z_jerk_rms')
# ('Y_jerk_max', 'Z_jerk_std')
# ('Y_jerk_max', 'total_jerk_min')
# ('Y_jerk_max', 'total_jerk_range')
# ('Y_jerk_max', 'total_jerk_rms')
# ('Y_jerk_max', 'total_jerk_std')
# ('Y_jerk_range', 'Y_jerk_rms')
# ('Y_jerk_range', 'Y_jerk_std')
# ('Y_jerk_range', 'Z_jerk_min')
# ('Y_jerk_range', 'Z_jerk_max')
# ('Y_jerk_range', 'Z_jerk_range')
# ('Y_jerk_range', 'Z_jerk_rms')
# ('Y_jerk_range', 'Z_jerk_std')
# ('Y_jerk_range', 'total_jerk_min')
# ('Y_jerk_range', 'total_jerk_max')
# ('Y_jerk_range', 'total_jerk_range')
# ('Y_jerk_range', 'total_jerk_rms')
# ('Y_jerk_range', 'total_jerk_std')
# ('Y_jerk_rms', 'Y_jerk_std')
# ('Y_jerk_rms', 'Z_jerk_min')
# ('Y_jerk_rms', 'Z_jerk_max')
# ('Y_jerk_rms', 'Z_jerk_range')
# ('Y_jerk_rms', 'Z_jerk_rms')
# ('Y_jerk_rms', 'Z_jerk_std')
# ('Y_jerk_rms', 'total_jerk_min')
# ('Y_jerk_rms', 'total_jerk_max')
# ('Y_jerk_rms', 'total_jerk_range')
# ('Y_jerk_rms', 'total_jerk_rms')
# ('Y_jerk_rms', 'total_jerk_std')
# ('Y_jerk_std', 'Z_jerk_min')
# ('Y_jerk_std', 'Z_jerk_max')
# ('Y_jerk_std', 'Z_jerk_range')
# ('Y_jerk_std', 'Z_jerk_rms')
# ('Y_jerk_std', 'Z_jerk_std')
# ('Y_jerk_std', 'total_jerk_min')
# ('Y_jerk_std', 'total_jerk_max')
# ('Y_jerk_std', 'total_jerk_range')
# ('Y_jerk_std', 'total_jerk_rms')
# ('Y_jerk_std', 'total_jerk_std')
# ('Z_jerk_min', 'Z_jerk_max')
# ('Z_jerk_min', 'Z_jerk_range')
# ('Z_jerk_min', 'Z_jerk_rms')
# ('Z_jerk_min', 'Z_jerk_std')
# ('Z_jerk_min', 'total_jerk_min')
# ('Z_jerk_min', 'total_jerk_max')
# ('Z_jerk_min', 'total_jerk_range')
# ('Z_jerk_min', 'total_jerk_rms')
# ('Z_jerk_min', 'total_jerk_std')
# ('Z_jerk_max', 'Z_jerk_range')
# ('Z_jerk_max', 'Z_jerk_rms')
# ('Z_jerk_max', 'Z_jerk_std')
# ('Z_jerk_max', 'total_jerk_min')
# ('Z_jerk_max', 'total_jerk_max')
# ('Z_jerk_max', 'total_jerk_range')
# ('Z_jerk_max', 'total_jerk_rms')
# ('Z_jerk_max', 'total_jerk_std')
# ('Z_jerk_range', 'Z_jerk_rms')
# ('Z_jerk_range', 'Z_jerk_std')
# ('Z_jerk_range', 'total_jerk_min')
# ('Z_jerk_range', 'total_jerk_max')
# ('Z_jerk_range', 'total_jerk_range')
# ('Z_jerk_range', 'total_jerk_rms')
# ('Z_jerk_range', 'total_jerk_std')
# ('Z_jerk_rms', 'Z_jerk_std')
# ('Z_jerk_rms', 'total_jerk_min')
# ('Z_jerk_rms', 'total_jerk_max')
# ('Z_jerk_rms', 'total_jerk_range')
# ('Z_jerk_rms', 'total_jerk_rms')
# ('Z_jerk_rms', 'total_jerk_std')
# ('Z_jerk_std', 'total_jerk_min')
# ('Z_jerk_std', 'total_jerk_max')
# ('Z_jerk_std', 'total_jerk_range')
# ('Z_jerk_std', 'total_jerk_rms')
# ('Z_jerk_std', 'total_jerk_std')
# ('total_jerk_min', 'total_jerk_range')
# ('total_jerk_min', 'total_jerk_rms')
# ('total_jerk_min', 'total_jerk_std')
# ('total_jerk_max', 'total_jerk_range')
# ('total_jerk_max', 'total_jerk_rms')
# ('total_jerk_max', 'total_jerk_std')
# ('total_jerk_range', 'total_jerk_rms')
# ('total_jerk_range', 'total_jerk_std')
# ('total_jerk_rms', 'total_jerk_std')

# %%
# Feature importance using RandomForest
X = df.drop('label', axis=1)  # Assuming 'target' is the target column
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Get feature importances
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
features = X.columns

# %%
# Plot the feature importances
plt.figure(figsize=(12, 6))
plt.title("Feature Importance")
plt.bar(range(X.shape[1]), importances[indices], align="center")
plt.xticks(range(X.shape[1]), features[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# %%
# Feature importance using mutual information
mi = mutual_info_classif(X_train, y_train)
mi = pd.Series(mi, index=X.columns)
mi.sort_values(ascending=False).plot.bar(figsize=(12, 6))
plt.title("Mutual Information of Features")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
k = 43  # Number of top features to select
selector = SelectKBest(score_func=chi2, k=k)
selector.fit(X_train,y_train)
# Out:
# SelectKBest(k=43, score_func=<function chi2 at 0x7b00211c1080>)

# %%
# Get the selected feature indices
selected_indices = selector.get_support(indices=True)
selected_features = X.columns[selected_indices]

# %%
scores = selector.scores_[selected_indices]

# %%
# Create a DataFrame for better visualization
feature_scores = pd.DataFrame({'Feature': selected_features, 'Chi2 Score': scores})
feature_scores = feature_scores.sort_values(by='Chi2 Score', ascending=False)

# %%
# Plot the Chi2 scores
plt.figure(figsize=(12, 6))
plt.barh(feature_scores['Feature'], feature_scores['Chi2 Score'], color='skyblue')
plt.xlabel('Chi2 Score')
plt.title('Top {} Features Selected by Chi2'.format(k))
plt.gca().invert_yaxis()
plt.show()

# %%
print("Selected Features:")
print(feature_scores)
# Out:
# Selected Features:
#              Feature  Chi2 Score
# 28        Y_jerk_rms  262.580022
# 29        Y_jerk_std  262.532075
# 26      Y_jerk_range  195.557210
# 14           Z_range  186.084063
# 34        Z_jerk_rms  185.712591
# 35        Z_jerk_std  185.388311
# 17             Z_std  180.733955
# 32      Z_jerk_range  180.354797
# 8            Y_range  170.810667
# 40    total_jerk_rms  167.717203
# 41    total_jerk_std  167.430820
# 31        Z_jerk_max  160.018126
# 11             Y_std  146.250352
# 38  total_jerk_range  142.433858
# 25        Y_jerk_max  139.140595
# 37    total_jerk_max  105.282344
# 10             Y_rms   74.157572
# 13             Z_max   66.687912
# 7              Y_max   48.862421
# 6              Y_min   46.550655
# 12             Z_min   40.495714
# 16             Z_rms   38.309721
# 24        Y_jerk_min   31.534686
# 30        Z_jerk_min   18.379353
# 36    total_jerk_min   14.761457
# 23        X_jerk_std   13.325092
# 22        X_jerk_rms   13.116710
# 5              X_std   12.531358
# 4              X_rms   10.183628
# 2            X_range    7.495488
# 20      X_jerk_range    7.287364
# 19        X_jerk_max    7.254402
# 15            Z_mean    6.175112
# 1              X_max    5.512857
# 3             X_mean    5.263101
# 9             Y_mean    3.840693
# 42   timestamp_range    3.264792
# 0              X_min    0.891065
# 18        X_jerk_min    0.624999
# 27       Y_jerk_mean    0.162012
# 39   total_jerk_mean    0.146563
# 21       X_jerk_mean    0.030163
# 33       Z_jerk_mean    0.022785
